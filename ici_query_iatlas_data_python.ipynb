# %% [markdown]
# # CRI iAtlas notebooks
# ## Exploring the Immune Checkpoint Inhibition data available in iAtlas in Python.
#
# Repo: https://github.com/CRI-iAtlas/iatlas-notebooks/
#
# Notebook: ici_query_iatlas_data_python.ipynb
#
# Date: July 1, 2024
#
# Author: Carolina Heimann

# %% [markdown]
# ---
#
# notebook repo: https://github.com/CRI-iAtlas/iatlas-notebooks
#
# landing page: https://www.cri-iatlas.org/
#
# portal: https://isb-cgc.shinyapps.io/iatlas/
#
# email: support@cri-iatlas.org
#
# ---

# %% [markdown]
# The CRI iAtlas database is available in a database that can be queried using the R package [`iatlasGraphQLClient`](https://github.com/CRI-iAtlas/iatlasGraphQLClient).
#
# For manipulating the data in Python, one can perform the queries in R (for more information, check our notebook on [Exploring the Immune Checkpoint Inhibition data available in iAtlas in R](https://github.com/CRI-iAtlas/iatlas-notebooks/blob/main/ici_query_iatlas_data.ipynb) and [Querying TCGA features and expression in R](https://github.com/CRI-iAtlas/iatlas-notebooks/blob/main/querying_TCGA_features_and_expression.ipynb)) and export the data for further analysis in Python, or use the libraries for interoperability between Python and R.
#
# In this notebook, we will use the `rpy2` library to query the CRI iAtlas database and explore the data the datasets with bulk RNAseq data from studies of response to Immune Checkpoint Inhibitors (ICI).

# %% [markdown]
# ## Getting started

# %%
#we'll need to use the R package that queries the iAtlas database, the libraries below are necessary to call R code
from rpy2.robjects.packages import importr
import rpy2.robjects as ro
from rpy2.robjects.conversion import localconverter
from rpy2.robjects import pandas2ri


#libraries for data manipulation
import pandas as pd

# %% [markdown]
# We need to run a few functions to call the interface between R and Python and for output formatting. The code below will be used anytime we need to get a table from the CRI iAtlas database.

# %%
#Adding the reference to querying the production version of the API
ro.globalenv["API_URL"] = "https://api.cri-iatlas.org/api"

#Code to query the iAtlas database and converting output to a pandas dataframe
iatlasGraphQLClient = importr('iatlasGraphQLClient') 

def get_dataframe_from_query(query_result):
    with localconverter(ro.default_converter + pandas2ri.converter):       
        return(ro.conversion.rpy2py(query_result))

# %% [markdown]
# # Exploring the ICI datasets and features
#
#
# The iAtlas ICI data is stored in a database that can be queried with functions from the `iatlasGraphQLClient` package.
# We have clinical data, immune features, scores of predictors of response to immunotherapy, and quantile normalized gene expression.
#
# You can get more information in iAtlas on [immune features and predictors of response to ICI](https://isb-cgc.shinyapps.io/iatlas/?module=datainfo), and our annotation of [immunomodulators](https://isb-cgc.shinyapps.io/iatlas/?module=immunomodulators) genes. You can access more information about these datasets in [iAtlas - ICI Datasets Overview](https://isb-cgc.shinyapps.io/iatlas/?module=ioresponse_overview) module.
#
# As a first step, let's take a look at the available datasets and features.

# %%
iatlas_datasets = get_dataframe_from_query(iatlasGraphQLClient.query_datasets())
iatlas_datasets
# Out:
#                                           display                     name  \
# 1                    Chen 2016 - SKCM, Anti-CTLA4        Chen_CanDisc_2016
# 2                      Choueiri 2016 - KIRC, PD-1        Choueiri_CCR_2016
# 3                                            GTEX                     GTEX
# 4                Gide 2019 - SKCM, PD-1 +/- CTLA4           Gide_Cell_2019
# 5                          Hugo 2016 - SKCM, PD-1        HugoLo_IPRES_2016
# 6                        IMVigor210 - BLCA, PD-L1               IMVigor210
# 7                       IMmotion150 - KIRC, PD-L1              IMmotion150
# 8                           Kim 2018 - STAD, PD-1          Kim_NatMed_2018
# 9                           Liu 2019 - SKCM, PD-1          Liu_NatMed_2019
# 10                   Melero 2019 - GBM, Anti-PD-1          Melero_GBM_2019
# 11        Miao 2018 - KIRC, PD-1 +/- CTLA4, PD-L1        Miao_Science_2018
# 12                                          PCAWG                    PCAWG
# 13  Prat 2017 - HNSC, LUAD, LUSC, SKCM, Anti-PD-1         Prat_CanRes_2017
# 14                         Prins 2019 - GBM, PD-1           Prins_GBM_2019
# 15                         Riaz 2017 - SKCM, PD-1      Riaz_Nivolumab_2017
# 16                                           TCGA                     TCGA
# 17                  Van Allen 2015 - SKCM, CTLA-4  VanAllen_antiCTLA4_2015
# 18                          Zhao 2019 - GBM, PD-1         Zhao_NatMed_2019
#
#         type
# 1        ici
# 2        ici
# 3      other
# 4        ici
# 5        ici
# 6        ici
# 7        ici
# 8        ici
# 9        ici
# 10       ici
# 11       ici
# 12  analysis
# 13       ici
# 14       ici
# 15       ici
# 16  analysis
# 17       ici
# 18       ici

# %%
iatlas_datasets["type"].value_counts()
# Out:
# type
# ici         15
# scrna        6
# analysis     2
# other        1
# Name: count, dtype: int64

# %% [markdown]
# In this notebook, we will explore the datasets of type `ici` , as those contain bulk RNAseq data from studies of response to Immune Checkpoint Inhibitors (ICI).
#
# The datasets of type `scrna` contain single-cell RNAseq data with annotation of immune cells. A few of them have ICI treatments.
#
# Finally, the other main type of dataset in CRI iAtlas is `analysis`, and these datasets are derived from cancer genomics efforts, The Cancer Genome Atlas (TCGA) and Pan-Cancer Analysis of Whole Genomes (PCAWG).

# %%
ici_datasets = iatlas_datasets[iatlas_datasets["type"] == "ici"]
ici_datasets
# Out:
#                                           display                     name  \
# 2                    Chen 2016 - SKCM, Anti-CTLA4        Chen_CanDisc_2016
# 3                      Choueiri 2016 - KIRC, PD-1        Choueiri_CCR_2016
# 5                Gide 2019 - SKCM, PD-1 +/- CTLA4           Gide_Cell_2019
# 6                          Hugo 2016 - SKCM, PD-1        HugoLo_IPRES_2016
# 7                        IMVigor210 - BLCA, PD-L1               IMVigor210
# 8                       IMmotion150 - KIRC, PD-L1              IMmotion150
# 9                           Kim 2018 - STAD, PD-1          Kim_NatMed_2018
# 12                          Liu 2019 - SKCM, PD-1          Liu_NatMed_2019
# 14                   Melero 2019 - GBM, Anti-PD-1          Melero_GBM_2019
# 15        Miao 2018 - KIRC, PD-1 +/- CTLA4, PD-L1        Miao_Science_2018
# 17  Prat 2017 - HNSC, LUAD, LUSC, SKCM, Anti-PD-1         Prat_CanRes_2017
# 18                         Prins 2019 - GBM, PD-1           Prins_GBM_2019
# 19                         Riaz 2017 - SKCM, PD-1      Riaz_Nivolumab_2017
# 22                  Van Allen 2015 - SKCM, CTLA-4  VanAllen_antiCTLA4_2015
# 24                          Zhao 2019 - GBM, PD-1         Zhao_NatMed_2019
#
#    type
# 2   ici
# 3   ici
# 5   ici
# 6   ici
# 7   ici
# 8   ici
# 9   ici
# 12  ici
# 14  ici
# 15  ici
# 17  ici
# 18  ici
# 19  ici
# 22  ici
# 24  ici

# %% [markdown]
# The display name of the datasets makes reference to the publication associated with the data, and also summarises the tumor type and ICI target involved in the study.

# %% [markdown]
# ## Immune Features

# %%
#immune features of all ICI samples.
with (ro.default_converter + pandas2ri.converter).context(): #we need this snippet of code when we want to send a parameter to the query
    features_df = (iatlasGraphQLClient.query_features(cohorts = ici_datasets["name"]))
features_df.head()
# Out:
#                                 name         display  \
# 1                 B_cells_Aggregate2         B Cells
# 2                 B_cells_Aggregate3         B Cells
# 3                     B_cells_memory  B Cells Memory
# 4                      B_cells_naive   B Cells Naive
# 5  BIOCARTA_CTLA4_V_Bindea_Th1_Cells    CTLA4 vs Th1
#
#                                                class       order      unit  \
# 1  Immune Cell Proportion - Common Lymphoid and M...           3  Fraction
# 2  Immune Cell Proportion - Differentiated Lympho...           4  Fraction
# 3                  Immune Cell Proportion - Original           9  Fraction
# 4                  Immune Cell Proportion - Original           8  Fraction
# 5  Predictor of Response to Immune Checkpoint Tre... -2147483648  Fraction
#
#       method_tag
# 1      CIBERSORT
# 2      CIBERSORT
# 3      CIBERSORT
# 4      CIBERSORT
# 5  NA_character_

# %% [markdown]
# ## Clinical Annotation

# %%
#clinical annotation that is available for the ici datasets
with (ro.default_converter + pandas2ri.converter).context():
    clinical_options = iatlasGraphQLClient.query_tags(datasets = ici_datasets["name"])
clinical_options.head()
# Out:
#            tag_name  tag_long_display tag_short_display  \
# 1       Biopsy_Site       Biopsy Site       Biopsy Site
# 2     Cancer_Tissue     Cancer Tissue     Cancer Tissue
# 3  Clinical_Benefit  Clinical Benefit  Clinical Benefit
# 4    Clinical_Stage    Clinical Stage    Clinical Stage
# 5              FFPE      FFPE Samples      FFPE Samples
#
#                                  tag_characteristics   tag_color  tag_order  \
# 1              Site where sample was collected from. -2147483648         18
# 2                             Original tumor tissue. -2147483648         14
# 3  Patients have clinical benefit when mRECIST re... -2147483648          4
# 4                          Clinical stage of cancer. -2147483648         17
# 5       Indicates whether the sample is FFPE or not. -2147483648         20
#
#        tag_type
# 1  parent_group
# 2  parent_group
# 3  parent_group
# 4  parent_group
# 5  parent_group

# %% [markdown]
# ## Gene Expression

# %%
#genes that we have expression data for all samples in the ici datasets (we will query expression values in the next section)
with (ro.default_converter + pandas2ri.converter).context():
    genes_df = iatlasGraphQLClient.query_genes(cohorts = ici_datasets["name"])
genes_df.head()
# Out:
#      hgnc  entrez                                        description  \
# 1   ABCB5  340273  A protein highly expressed by melanoma cell, a...
# 2   ABCC1    4363  MRP1 is a membrane transporter and it allows t...
# 3   ACKR3   57007  CXCR7 is the receptor for chemokines CXCL11 an...
# 4    ACP3      55  A enzyme produced by the prostate and generall...
# 5  ADAM17    6868  Belongs to metallopeptidase family and help th...
#
#    friendly_name io_landscape_name    gene_family  gene_function  \
# 1  NA_character_             ABCB5  NA_character_  NA_character_
# 2  NA_character_              MRP1  NA_character_  NA_character_
# 3  NA_character_             CXCR7  NA_character_  NA_character_
# 4  NA_character_              ACPP  NA_character_  NA_character_
# 5  NA_character_            ADAM17  NA_character_  NA_character_
#
#   immune_checkpoint                                 pathway super_category
# 1     NA_character_  ABC-family proteins mediated transport  NA_character_
# 2     NA_character_  ABC-family proteins mediated transport  NA_character_
# 3     NA_character_             Chemokine signaling pathway  NA_character_
# 4     NA_character_                    Innate Immune System  NA_character_
# 5     NA_character_                        Metallopeptidase  NA_character_

# %% [markdown]
# ## Annotation of response to immunotherapy
#
# One key annotation in the ICI datasets is how a patient responds to immunotherapy. The response to therapy with Immune Checkpoint Inhitbitor is originally annotated following the guidelines of mRECIST, and has 4 different levels.

# %%
with (ro.default_converter + pandas2ri.converter).context():
    df = iatlasGraphQLClient.query_tags(parent_tags = "Response")
df
# Out:
#                        tag_name     tag_long_display    tag_short_display  \
# 1    complete_response_response    Complete Response    Complete Response
# 2                   na_response        Not available        Not available
# 3     partial_response_response     Partial Response     Partial Response
# 4  progressive_disease_response  Progressive Disease  Progressive Disease
# 5       stable_disease_response       Stable Disease       Stable Disease
#
#                                  tag_characteristics tag_color  tag_order  \
# 1  Complete Response (CR) following modified Resp...   #009E73          1
# 2                 Response information not available   #868A88          5
# 3  Partial Response (PR) following modified Respo...   #0072B2          2
# 4  Progressive Disease (PD) following modified Re...   #D55E00          4
# 5  Stable Disease (SD) following modified Respons...   #F0E442          3
#
#   tag_type
# 1    group
# 2    group
# 3    group
# 4    group
# 5    group

# %% [markdown]
# The mRECIST annotation is used to annotate three other categories: Responder, Clinical Benefit and Progressor, which consist in grouping different levels of mRECIST into two categories.

# %%
outcome_variables  = ["Responder", "Clinical_Benefit", "Progression"]
get_dataframe_from_query(
    iatlasGraphQLClient.query_tags_with_parent_tags(parent_tags = outcome_variables)
    )[["parent_tag_name", "parent_tag_characteristics", "tag_name", "tag_short_display", "tag_characteristics"]]
# Out:
#     parent_tag_name                         parent_tag_characteristics  \
# 1  Clinical_Benefit  Patients have clinical benefit when mRECIST re...
# 2       Progression  Progressors are defined as patients with mRECI...
# 3         Responder  Responders are defined as patients with mRECIS...
# 4  Clinical_Benefit  Patients have clinical benefit when mRECIST re...
# 5       Progression  Progressors are defined as patients with mRECI...
# 6         Responder  Responders are defined as patients with mRECIS...
# 7  Clinical_Benefit  Patients have clinical benefit when mRECIST re...
# 8       Progression  Progressors are defined as patients with mRECI...
# 9         Responder  Responders are defined as patients with mRECIS...
#
#                  tag_name    tag_short_display  \
# 1  false_clinical_benefit  No Clinical Benefit
# 2       false_progression       Non-Progressor
# 3         false_responder        Non-Responder
# 4     na_clinical_benefit        Not available
# 5          na_progression        Not available
# 6            na_responder        Not available
# 7   true_clinical_benefit     Clinical Benefit
# 8        true_progression           Progressor
# 9          true_responder            Responder
#
#                                  tag_characteristics
# 1        Patient with mRECIST of Progressive Disease
# 2  Patient with mRECIST of Complete Response, Par...
# 3  Patient with mRECIST of Progressive Disease or...
# 4         Clinical Benefit information not available
# 5              Progression information not available
# 6                Responder information not available
# 7  Patient with mRECIST of Complete Response, Par...
# 8        Patient with mRECIST of Progressive Disease
# 9  Patient with mRECIST of Partial Response or Co...

# %% [markdown]
# ## Samples and treatments available
#
# Now, let's take a closer look at the ICI datasets that we have available. First, we will query our database and organize the results to see the TCGA Study and drug administered at each one of the studies:

# %%
#Treatment information
overview_treatment = ["TCGA_Study", "ICI_Rx"] #name of the groups of interest. Check the clinical_options df for more options

#Organize a dataframe with all patients IDs and samples IDs
with (ro.default_converter + pandas2ri.converter).context(): 
  all_ici_patients = iatlasGraphQLClient.query_dataset_samples(datasets = ici_datasets["name"]).merge( #add patient id info
    get_dataframe_from_query(iatlasGraphQLClient.query_sample_patients()))

#now we add the treatment information
with (ro.default_converter + pandas2ri.converter).context():
  #query the values of TCGA_Study and ICI_Rx for each sample
  treatment_df = iatlasGraphQLClient.query_tag_samples_parents(parent_tags = overview_treatment).merge( 
    all_ici_patients
  )

# %%
# We can summarise the information in this dataframe
summary = treatment_df.groupby(['dataset_display', 'parent_tag_name', 'tag_name']).agg(
    n_samples=pd.NamedAgg(column='sample_name', aggfunc='size'),
    n_patients=pd.NamedAgg(column='patient_name', aggfunc='nunique')
).reset_index()
summary
# Out:
#                                   dataset_display parent_tag_name  \
# 0                      Choueiri 2016 - KIRC, PD-1          ICI_Rx
# 1                Gide 2019 - SKCM, PD-1 +/- CTLA4          ICI_Rx
# 2                Gide 2019 - SKCM, PD-1 +/- CTLA4          ICI_Rx
# 3                        IMVigor210 - BLCA, PD-L1          ICI_Rx
# 4                        IMVigor210 - BLCA, PD-L1      TCGA_Study
# 5                       IMmotion150 - KIRC, PD-L1          ICI_Rx
# 6                           Liu 2019 - SKCM, PD-1          ICI_Rx
# 7                    Melero 2019 - GBM, Anti-PD-1          ICI_Rx
# 8         Miao 2018 - KIRC, PD-1 +/- CTLA4, PD-L1          ICI_Rx
# 9         Miao 2018 - KIRC, PD-1 +/- CTLA4, PD-L1          ICI_Rx
# 10  Prat 2017 - HNSC, LUAD, LUSC, SKCM, Anti-PD-1          ICI_Rx
# 11                         Prins 2019 - GBM, PD-1      TCGA_Study
# 12                         Riaz 2017 - SKCM, PD-1          ICI_Rx
# 13                          Zhao 2019 - GBM, PD-1          ICI_Rx
# 14                          Zhao 2019 - GBM, PD-1      TCGA_Study
#
#                     tag_name  n_samples  n_patients
# 0                  nivolumab         32          16
# 1   ipilimumab_pembrolizumab         32          26
# 2                  nivolumab         22           9
# 3               atezolizumab        348         348
# 4                       BLCA        348         348
# 5               atezolizumab        174         174
# 6                  nivolumab        102          51
# 7                  nivolumab        120          30
# 8               atezolizumab          2           2
# 9                  nivolumab         22          11
# 10                 nivolumab         56          28
# 11                       GBM         30          30
# 12                 nivolumab        214          64
# 13                 nivolumab         56          13
# 14                       GBM         34          17

# %% [markdown]
# Some of these datasets have more than one sample per patient - in those studies, some patients had samples collected before (pre_sample_treatment) and during (on_sample_treatment) ICI therapy.

# %%
with (ro.default_converter + pandas2ri.converter).context():
    timepoint = all_ici_patients.merge(
        iatlasGraphQLClient.query_tag_samples_parents(parent_tags = "Sample_Treatment"),
    ).groupby(['dataset_display', 'parent_tag_name', 'tag_name']).agg(
        n_samples=pd.NamedAgg(column='sample_name', aggfunc='size'),
        n_patients=pd.NamedAgg(column='patient_name', aggfunc='nunique')
    ).reset_index()

timepoint
# Out:
#                                   dataset_display   parent_tag_name  \
# 0                    Chen 2016 - SKCM, Anti-CTLA4  Sample_Treatment
# 1                    Chen 2016 - SKCM, Anti-CTLA4  Sample_Treatment
# 2                    Chen 2016 - SKCM, Anti-CTLA4  Sample_Treatment
# 3                      Choueiri 2016 - KIRC, PD-1  Sample_Treatment
# 4                Gide 2019 - SKCM, PD-1 +/- CTLA4  Sample_Treatment
# 5                Gide 2019 - SKCM, PD-1 +/- CTLA4  Sample_Treatment
# 6                          Hugo 2016 - SKCM, PD-1  Sample_Treatment
# 7                          Hugo 2016 - SKCM, PD-1  Sample_Treatment
# 8                        IMVigor210 - BLCA, PD-L1  Sample_Treatment
# 9                       IMmotion150 - KIRC, PD-L1  Sample_Treatment
# 10                          Kim 2018 - STAD, PD-1  Sample_Treatment
# 11                          Liu 2019 - SKCM, PD-1  Sample_Treatment
# 12                   Melero 2019 - GBM, Anti-PD-1  Sample_Treatment
# 13                   Melero 2019 - GBM, Anti-PD-1  Sample_Treatment
# 14        Miao 2018 - KIRC, PD-1 +/- CTLA4, PD-L1  Sample_Treatment
# 15  Prat 2017 - HNSC, LUAD, LUSC, SKCM, Anti-PD-1  Sample_Treatment
# 16                         Prins 2019 - GBM, PD-1  Sample_Treatment
# 17                         Prins 2019 - GBM, PD-1  Sample_Treatment
# 18                         Riaz 2017 - SKCM, PD-1  Sample_Treatment
# 19                         Riaz 2017 - SKCM, PD-1  Sample_Treatment
# 20                  Van Allen 2015 - SKCM, CTLA-4  Sample_Treatment
# 21                          Zhao 2019 - GBM, PD-1  Sample_Treatment
# 22                          Zhao 2019 - GBM, PD-1  Sample_Treatment
#
#                  tag_name  n_samples  n_patients
# 0     on_sample_treatment         15          15
# 1   post_sample_treatment          7           7
# 2    pre_sample_treatment         32          31
# 3    pre_sample_treatment         16          16
# 4     on_sample_treatment         18          18
# 5    pre_sample_treatment         73          73
# 6     on_sample_treatment          1           1
# 7    pre_sample_treatment         26          26
# 8    pre_sample_treatment        348         348
# 9    pre_sample_treatment        263         263
# 10   pre_sample_treatment         45          45
# 11   pre_sample_treatment        122         122
# 12    on_sample_treatment         30          30
# 13   pre_sample_treatment         30          30
# 14   pre_sample_treatment         17          17
# 15   pre_sample_treatment         65          65
# 16    on_sample_treatment         15          15
# 17   pre_sample_treatment         15          15
# 18    on_sample_treatment         56          56
# 19   pre_sample_treatment         51          51
# 20   pre_sample_treatment         42          41
# 21    on_sample_treatment          9           7
# 22   pre_sample_treatment         25          16

# %% [markdown]
# # Querying the CRI iAtlas database
#
# Each type of data has a query function in `iatlasGraphQLClient`, as summarized below:
#
# - For immunefeatures: `iatlasGraphQLClient.query_feature_values()`
# - For gene expression data: `iatlasGraphQLClient.query_gene_expression()`
# - For clinical annotation: `iatlasGraphQLClient.query_tag_samples_parents()`
#
# To illustrate how to get the ICI data from the iAtlas database, we will get the data that follows the parameters listed below:
#
# - *Dataset:* Hugo 2016 - SKCM, PD-1
#
# - *Features:* IMPRES (Auslander et al, 2018), IPRES (Vincent lab analysis of Hugo et al data, unpublished), Cytolytic Score (Roufas et al, 2018), CTLA4/Th1 (Nishimura, 2004; Bindea et al., 2013)
#
# - *Gene expression:* ADORA2A, CTLA4, EDNRB, TLR4
#
# - *Clinical Annotation:* Response, Gender.

# %%
with (ro.default_converter + pandas2ri.converter).context():
    #For immune features, use names from features_df["name"]
    features = iatlasGraphQLClient.query_feature_values(cohorts = "HugoLo_IPRES_2016", 
                                                        features = ["IMPRES", 
                                                                    "Vincent_IPRES_NonResponder", 
                                                                    "Cytolytic_Score", 
                                                                    "BIOCARTA_CTLA4_V_Bindea_Th1_Cells"]) 

    #For gene expression, we need the gene Entrez ID to query the iAtlas database
    genes_entrez = [135,
                    1493,
                    1910,
                    7099]

    genes = iatlasGraphQLClient.query_gene_expression(cohorts = "HugoLo_IPRES_2016", 
                                                    entrez = genes_entrez)

    #For clinical annotation, use names from clinical_options["tag_name"] that have tag_type == "parent_tag"

    clinical_annotation  = iatlasGraphQLClient.query_tag_samples_parents(cohorts = "HugoLo_IPRES_2016", 
                                                        parent_tags = ["Response", "Gender"])

# %% [markdown]
# All tables are in long format

# %%
#All the tables are in the long format.
features.head()
# Out:
#                           sample                       feature_name  \
# 1  HugoLo_IPRES_2016-Pt01-ar-279  BIOCARTA_CTLA4_V_Bindea_Th1_Cells
# 2  HugoLo_IPRES_2016-Pt02-ar-280  BIOCARTA_CTLA4_V_Bindea_Th1_Cells
# 3  HugoLo_IPRES_2016-Pt04-ar-281  BIOCARTA_CTLA4_V_Bindea_Th1_Cells
# 4  HugoLo_IPRES_2016-Pt05-ar-282  BIOCARTA_CTLA4_V_Bindea_Th1_Cells
# 5  HugoLo_IPRES_2016-Pt06-ar-283  BIOCARTA_CTLA4_V_Bindea_Th1_Cells
#
#   feature_display  feature_value  feature_order  \
# 1    CTLA4 vs Th1       1.001012    -2147483648
# 2    CTLA4 vs Th1       1.190649    -2147483648
# 3    CTLA4 vs Th1       1.179757    -2147483648
# 4    CTLA4 vs Th1       1.171726    -2147483648
# 5    CTLA4 vs Th1       1.290074    -2147483648
#
#                                        feature_class
# 1  Predictor of Response to Immune Checkpoint Tre...
# 2  Predictor of Response to Immune Checkpoint Tre...
# 3  Predictor of Response to Immune Checkpoint Tre...
# 4  Predictor of Response to Immune Checkpoint Tre...
# 5  Predictor of Response to Immune Checkpoint Tre...

# %%
genes.head()
# Out:
#                           sample  entrez  hgnc  rna_seq_expr
# 1  HugoLo_IPRES_2016-Pt20-ar-294    7099  TLR4      1315.887
# 2  HugoLo_IPRES_2016-Pt22-ar-295    7099  TLR4      4520.116
# 3  HugoLo_IPRES_2016-Pt05-ar-282    7099  TLR4       394.303
# 4  HugoLo_IPRES_2016-Pt14-ar-290    7099  TLR4      2374.693
# 5  HugoLo_IPRES_2016-Pt06-ar-283    7099  TLR4      3383.161

# %%
clinical_annotation.head()
# Out:
#                      sample_name parent_tag_name parent_tag_long_display  \
# 1  HugoLo_IPRES_2016-Pt08-ar-285        Response        mRECIST Response
# 2  HugoLo_IPRES_2016-Pt27-ar-298        Response        mRECIST Response
# 3  HugoLo_IPRES_2016-Pt13-ar-289        Response        mRECIST Response
# 4  HugoLo_IPRES_2016-Pt09-ar-286        Response        mRECIST Response
# 5  HugoLo_IPRES_2016-Pt05-ar-282        Response        mRECIST Response
#
#   parent_tag_short_display                         parent_tag_characteristics  \
# 1         mRECIST Response  Response to treatment following modified Respo...
# 2         mRECIST Response  Response to treatment following modified Respo...
# 3         mRECIST Response  Response to treatment following modified Respo...
# 4         mRECIST Response  Response to treatment following modified Respo...
# 5         mRECIST Response  Response to treatment following modified Respo...
#
#    parent_tag_color  parent_tag_order parent_tag_type  \
# 1       -2147483648                 1    parent_group
# 2       -2147483648                 1    parent_group
# 3       -2147483648                 1    parent_group
# 4       -2147483648                 1    parent_group
# 5       -2147483648                 1    parent_group
#
#                      tag_name   tag_long_display  tag_short_display  \
# 1  complete_response_response  Complete Response  Complete Response
# 2  complete_response_response  Complete Response  Complete Response
# 3  complete_response_response  Complete Response  Complete Response
# 4  complete_response_response  Complete Response  Complete Response
# 5   partial_response_response   Partial Response   Partial Response
#
#                                  tag_characteristics tag_color  tag_order  \
# 1  Complete Response (CR) following modified Resp...   #009E73          1
# 2  Complete Response (CR) following modified Resp...   #009E73          1
# 3  Complete Response (CR) following modified Resp...   #009E73          1
# 4  Complete Response (CR) following modified Resp...   #009E73          1
# 5  Partial Response (PR) following modified Respo...   #0072B2          2
#
#   tag_type
# 1    group
# 2    group
# 3    group
# 4    group
# 5    group
